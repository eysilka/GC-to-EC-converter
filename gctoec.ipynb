# %%
def gc2ec(gcd):
  gcd = gcd.split('-', 3)

  ey = int(gcd[0])-7 if ((int(gcd[0])-7)%4==0 and int(gcd[1])>9 or int(gcd[1])==9 and int(gcd[2])>11) or (int(gcd[1])>9 or int(gcd[1])==9 and int(gcd[2])>10) else int(gcd[0])-8
  em = 0
  if (int(gcd[1])==9 and int(gcd[2])>5 and ((int(gcd[0])-7)%4==0 and int(gcd[2])<12 or int(gcd[2])<11)):
    ed = int(gcd[2])-5
    em = 13
  elif (int(gcd[1]) in [9,10] or (int(gcd[0])-7)%4==0 and int(gcd[1]) in [11,12]):
    if int(gcd[2])>10:
      ed = int(gcd[2])-10
      em = int(gcd[1])-8
    else:
      ed = int(gcd[2])+20
      em = int(gcd[1])-9 if int(gcd[1])>9 else int(gcd[1])-8
  elif (int(gcd[1]) in [3,11,12] or (int(gcd[0])-7)%4==0 and int(gcd[1])==1):
    if int(gcd[2])>9:
      ed = int(gcd[2])-9
      em = int(gcd[1])-8 if int(gcd[1]) in [11,12] else int(gcd[1])+4
    else:
      ed = int(gcd[2])+21
      em = int(gcd[1])-9 if int(gcd[1]) in [11,12] else int(gcd[1])+3
  elif (int(gcd[1]) in [1,4,5] or (int(gcd[0])-7)%4==0 and int(gcd[1])==2):
    if int(gcd[2])>8:
      ed = int(gcd[2])-8
      em = int(gcd[1])+4
    else:
      ed = int(gcd[2])+22
      em = int(gcd[1])+3
  elif (int(gcd[1]) in [2,6,7]):
    if int(gcd[2])>7:
      ed = int(gcd[2])-7
      em = int(gcd[1])+4
    else:
      ed = int(gcd[2])+23
      em = int(gcd[1])+3
  else:
    if int(gcd[2])>6:
      ed = int(gcd[2])-6
      em = int(gcd[1])+4
    else:
      ed = int(gcd[2])+24
      em = int(gcd[1])+3

  em='0'+str(em) if em<10 else str(em)
  ed='0'+str(ed) if ed<10 else str(ed)
  ecd=[str(ey),'-',em,'-',ed]
  ecd=''.join(ecd)

  return ecd
ec = gc2ec('2024-09-10')
ec
# Out:
# '2016-13-05'

# %%
et_months = ["መስከረም", "ጥቅምት", "ኅዳር", "ታኅሣሥ", "ጥር", "የካቲት", "መጋቢት", "ሚያዝያ", "ግንቦት", "ሰኔ", "ሐምሌ", "ነሐሴ", "ጳጉሜን"]
et_days = {"እሑድ", "ሰኞ", "ማክሰኞ", "ረቡዕ", "ሓሙስ", "ዓርብ", "ቅዳሜ"}

em_name = et_months[int(ec.split('-')[1])-1]

em_name
# Out:
# 'ጳጉሜን'
